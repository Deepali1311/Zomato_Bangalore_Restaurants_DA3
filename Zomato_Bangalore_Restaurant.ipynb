# %% [markdown]
# #"Zomato_Bangalore_Restaurant"!
# ![zomato-rep.jpg](data:image/jpeg;base64,...)

# %%
# !pip install opendatasets --upgrade  --quiet

# %% [markdown]
# ####Importing Libraries

# %%
import opendatasets as od
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ####Downloading Dataset (Directly from source - Kaggle)

# %% [markdown]
# kaggle key:
# feeeaf503f91a8b8ecf7ff39fd50ee07

# %%
url =('https://www.kaggle.com/himanshupoddar/zomato-bangalore-restaurants')
od.download(url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: deepali3005
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 89.0M/89.0M [00:01<00:00, 54.2MB/s]

# %%
data_filename='./zomato-bangalore-restaurants/zomato.csv'

# %% [markdown]
# ####Reading the dataset

# %%
df=pd.read_csv(data_filename)
df.head(5)
# Out:
#                                                  url  ... listed_in(city)
# 0  https://www.zomato.com/bangalore/jalsa-banasha...  ...    Banashankari
# 1  https://www.zomato.com/bangalore/spice-elephan...  ...    Banashankari
# 2  https://www.zomato.com/SanchurroBangalore?cont...  ...    Banashankari
# 3  https://www.zomato.com/bangalore/addhuri-udupi...  ...    Banashankari
# 4  https://www.zomato.com/bangalore/grand-village...  ...    Banashankari
#
# [5 rows x 17 columns]

# %% [markdown]
# ####Getting insights of dataset

# %%
df.dtypes                             # Columns type
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.columns                               # Name of all the columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.columns.value_counts().sum()                          # Total number of columns
# Out:
# 17

# %%
df.info()                               # Basic information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.describe()                                   # Statistical function
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.shape                                   # total rows and columns
# Out:
# (51717, 17)

# %% [markdown]
# ###Wrangling the data

# %% [markdown]
# ####
# Drop unnecessary columns
# checking missing values
